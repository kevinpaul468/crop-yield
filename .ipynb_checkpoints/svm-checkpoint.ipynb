# %%
import pandas as pd
import sklearn
import warnings

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn import svm
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_12501/3213757128.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('data.csv')
print(df)
# Out:
#     Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0             1230          80          28            80              24
# 1              480          60          36            70              20
# 2             1250          75          29            78              22
# 3              450          65          35            70              19
# 4             1200          80          27            79              22
# ..             ...         ...         ...           ...             ...
# 94            1250          77          28            78              23
# 95             425          60          39            65              19
# 96            1220          79          28            77              23
# 97             480          65          36            68              21
# 98            1230          80          28            80              24
#
#     Potassium (K)  Yeild (Q/acre)
# 0              20              12
# 1              18               8
# 2              19              11
# 3              18               9
# 4              19              11
# ..            ...             ...
# 94             20               9
# 95             17               7
# 96             21              11
# 97             16               7
# 98             20              12
#
# [99 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rain Fall (mm)  99 non-null     int64
#  1   Fertilizer      99 non-null     int64
#  2   Temperatue      99 non-null     int64
#  3   Nitrogen (N)    99 non-null     int64
#  4   Phosphorus (P)  99 non-null     int64
#  5   Potassium (K)   99 non-null     int64
#  6   Yeild (Q/acre)  99 non-null     int64
# dtypes: int64(7)
# memory usage: 5.5 KB

# %%
x = df.iloc[:, :6].values
y = df.iloc[:, 6].values

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
regr = svm.SVR()

# %%
regr.fit(X_train, y_train)
# Out:
# SVR()

# %%
print("Training data:")
print(f"r2 score: {r2_score(y_train, regr.predict(X_train))}")
print(f"mean absolute error: {mean_absolute_error(y_train, regr.predict(X_train))}")
# Out:
# Training data:
# r2 score: 0.7710419623963436
# mean absolute error: 0.7227888180015098

# %%
print("Testing data:")
print(f"r2 score: {r2_score(y_test, regr.predict(X_test))}")
print(f"mean absolute error: {mean_absolute_error(y_test, regr.predict(X_test))}")
# Out:
# Testing data:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("Testing data:")
# ----> 2 print(f"r2 score: {r2_score(y_test, regr.predict(X_test))}")
#       3 print(f"mean absolute error: {mean_absolute_error(y_test, regr.predict(X_test))}")
#
# NameError: name 'r2_score' is not defined

# %%
from sklearn.model_selection import LearningCurveDisplay

LearningCurveDisplay.from_estimator(svm, x, y)
plt.savefig("my_plot1.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from sklearn.model_selection import LearningCurveDisplay
# ----> 3 LearningCurveDisplay.from_estimator(svm, x, y)
#       4 plt.savefig("my_plot1.png")
#
# NameError: name 'svm' is not defined
